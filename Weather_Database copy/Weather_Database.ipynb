# %%
# Deliverable 1: Retrieve Weather Data
# 1. Create a folder called Weather_Database
# 2. Create a new Jupyter Notebook file to retrieve the weather data, and name it Weather_Database.ipynb.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# the output is a zip object in memory

# %%
# let's unpack our lat_lngs zip object into a list
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/drrigalt/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/drrigalt/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 4. Get the nearest city using the citipy module.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Perform an API call with the OpenWeatherMap.

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d68768f4a6bc90bfdfdccd0e08a81b7

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d68768f4a6bc90bfdfdccd0e08a81b7&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 57.85,
#   'feels_like': 57.33,
#   'temp_min': 53.53,
#   'temp_max': 61.32,
#   'pressure': 1014,
#   'humidity': 85},
#  'visibility': 10000,
#  'wind': {'speed': 5.75, 'deg': 140},
#  'clouds': {'all': 75},
#  'dt': 1634776591,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1634727781,
#   'sunset': 1634766877},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 57.96,
#   'feels_like': 57.4,
#   'temp_min': 53.53,
#   'temp_max': 61.32,
#   'pressure': 1014,
#   'humidity': 84},
#  'visibility': 10000,
#  'wind': {'speed': 5.75, 'deg': 140},
#  'clouds': {'all': 75},
#  'dt': 1634776466,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1634727781,
#   'sunset': 1634766877},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Convert the Date Timestamp
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Get the City Weather Data

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
       
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tura
# Processing Record 2 of Set 1 | komsomolskiy
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | kalat
# Processing Record 5 of Set 1 | nata
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | morondava
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | vila franca do campo
# Processing Record 16 of Set 1 | cidreira
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | arman
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | qarqin
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | constitucion
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | estevan
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | meulaboh
# Processing Record 27 of Set 1 | antsohihy
# Processing Record 28 of Set 1 | harper
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | norman wells
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | tucuma
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | katangli
# Processing Record 36 of Set 1 | el faiyum
# City not found. Skipping...
# Processing Record 37 of Set 1 | zhigansk
# Processing Record 38 of Set 1 | mabama
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | kamenka
# Processing Record 41 of Set 1 | capitao poco
# Processing Record 42 of Set 1 | geraldton
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | xichang
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | broken hill
# Processing Record 48 of Set 1 | kilemary
# Processing Record 49 of Set 1 | cabo san lucas
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | clarence town
# Processing Record 2 of Set 2 | qandala
# Processing Record 3 of Set 2 | le port
# Processing Record 4 of Set 2 | koumac
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | odda
# Processing Record 7 of Set 2 | avinurme
# Processing Record 8 of Set 2 | ribeira brava
# Processing Record 9 of Set 2 | bintulu
# Processing Record 10 of Set 2 | sambava
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | katobu
# Processing Record 13 of Set 2 | kaniama
# Processing Record 14 of Set 2 | fukue
# Processing Record 15 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | roald
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | balkanabat
# Processing Record 21 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 22 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 2 | bahia blanca
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | troitskoye
# Processing Record 28 of Set 2 | raudeberg
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | dipkarpaz
# City not found. Skipping...
# Processing Record 34 of Set 2 | havelock
# Processing Record 35 of Set 2 | olafsvik
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | sitka
# Processing Record 38 of Set 2 | agadir
# Processing Record 39 of Set 2 | khandagayty
# Processing Record 40 of Set 2 | erin
# Processing Record 41 of Set 2 | narsaq
# Processing Record 42 of Set 2 | saint-joseph
# Processing Record 43 of Set 2 | jubayl
# City not found. Skipping...
# Processing Record 44 of Set 2 | lobito
# Processing Record 45 of Set 2 | ust-kuyga
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | wanxian
# Processing Record 48 of Set 2 | monrovia
# Processing Record 49 of Set 2 | san cristobal
# Processing Record 50 of Set 2 | dingle
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | srednekolymsk
# Processing Record 3 of Set 3 | buala
# Processing Record 4 of Set 3 | sokoni
# Processing Record 5 of Set 3 | diffa
# Processing Record 6 of Set 3 | biograd na moru
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | talnakh
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | gizo
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | barry
# Processing Record 15 of Set 3 | denpasar
# Processing Record 16 of Set 3 | vyshhorod
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | oistins
# Processing Record 19 of Set 3 | prestea
# Processing Record 20 of Set 3 | sur
# Processing Record 21 of Set 3 | havoysund
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 3 | tome
# Processing Record 25 of Set 3 | barrow
# Processing Record 26 of Set 3 | rocha
# Processing Record 27 of Set 3 | hasaki
# Processing Record 28 of Set 3 | gamba
# Processing Record 29 of Set 3 | vila velha
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | mantua
# Processing Record 32 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 3 | matay
# Processing Record 34 of Set 3 | birjand
# Processing Record 35 of Set 3 | derzhavinsk
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 3 | port lincoln
# Processing Record 40 of Set 3 | garden city
# Processing Record 41 of Set 3 | rabat
# Processing Record 42 of Set 3 | vao
# Processing Record 43 of Set 3 | lahat
# Processing Record 44 of Set 3 | vardo
# Processing Record 45 of Set 3 | boyolangu
# Processing Record 46 of Set 3 | souillac
# Processing Record 47 of Set 3 | luderitz
# Processing Record 48 of Set 3 | faanui
# Processing Record 49 of Set 3 | egvekinot
# Processing Record 50 of Set 3 | adrar
# Processing Record 1 of Set 4 | villanueva de la serena
# Processing Record 2 of Set 4 | kavieng
# Processing Record 3 of Set 4 | amazar
# Processing Record 4 of Set 4 | oranjemund
# Processing Record 5 of Set 4 | lompoc
# Processing Record 6 of Set 4 | warrington
# Processing Record 7 of Set 4 | asau
# Processing Record 8 of Set 4 | minbu
# Processing Record 9 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 4 | pangody
# Processing Record 11 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 4 | kampong chhnang
# Processing Record 13 of Set 4 | pombas
# Processing Record 14 of Set 4 | lixourion
# Processing Record 15 of Set 4 | victoria
# Processing Record 16 of Set 4 | goure
# Processing Record 17 of Set 4 | ust-nera
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | sao filipe
# Processing Record 20 of Set 4 | genoa
# Processing Record 21 of Set 4 | nokaneng
# Processing Record 22 of Set 4 | san jose del guaviare
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | saint-philippe
# Processing Record 25 of Set 4 | santarem
# Processing Record 26 of Set 4 | mwinilunga
# Processing Record 27 of Set 4 | antofagasta
# Processing Record 28 of Set 4 | dire dawa
# Processing Record 29 of Set 4 | hatfield
# Processing Record 30 of Set 4 | iquique
# Processing Record 31 of Set 4 | hegang
# Processing Record 32 of Set 4 | tilichiki
# Processing Record 33 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 4 | saryg-sep
# Processing Record 35 of Set 4 | naryan-mar
# Processing Record 36 of Set 4 | mouzouras
# Processing Record 37 of Set 4 | lagoa
# Processing Record 38 of Set 4 | tual
# Processing Record 39 of Set 4 | venado tuerto
# Processing Record 40 of Set 4 | bengkulu
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | coalville
# Processing Record 43 of Set 4 | iqaluit
# Processing Record 44 of Set 4 | kirkwall
# Processing Record 45 of Set 4 | pacific grove
# Processing Record 46 of Set 4 | flinders
# Processing Record 47 of Set 4 | camacha
# Processing Record 48 of Set 4 | college
# Processing Record 49 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 4 | airai
# Processing Record 1 of Set 5 | labuhan
# Processing Record 2 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 5 | thompson
# Processing Record 4 of Set 5 | torbay
# Processing Record 5 of Set 5 | thomaston
# Processing Record 6 of Set 5 | tucurui
# Processing Record 7 of Set 5 | ola
# Processing Record 8 of Set 5 | andenes
# Processing Record 9 of Set 5 | kajaani
# Processing Record 10 of Set 5 | alice springs
# Processing Record 11 of Set 5 | winona
# Processing Record 12 of Set 5 | okhotsk
# Processing Record 13 of Set 5 | vostok
# Processing Record 14 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 5 | turukhansk
# Processing Record 16 of Set 5 | thinadhoo
# Processing Record 17 of Set 5 | nome
# Processing Record 18 of Set 5 | qaanaaq
# Processing Record 19 of Set 5 | kruisfontein
# Processing Record 20 of Set 5 | mahebourg
# Processing Record 21 of Set 5 | durant
# Processing Record 22 of Set 5 | pisco
# Processing Record 23 of Set 5 | suao
# City not found. Skipping...
# Processing Record 24 of Set 5 | darnah
# Processing Record 25 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 5 | ajdabiya
# Processing Record 27 of Set 5 | poco das trincheiras
# Processing Record 28 of Set 5 | provideniya
# Processing Record 29 of Set 5 | gebze
# Processing Record 30 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 5 | quatre cocos
# Processing Record 32 of Set 5 | machico
# Processing Record 33 of Set 5 | isangel
# Processing Record 34 of Set 5 | talara
# Processing Record 35 of Set 5 | leshukonskoye
# Processing Record 36 of Set 5 | yarada
# Processing Record 37 of Set 5 | manoel urbano
# Processing Record 38 of Set 5 | pehowa
# Processing Record 39 of Set 5 | kem
# Processing Record 40 of Set 5 | urumqi
# Processing Record 41 of Set 5 | canchungo
# Processing Record 42 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 5 | saskylakh
# Processing Record 44 of Set 5 | karlstad
# Processing Record 45 of Set 5 | black river
# Processing Record 46 of Set 5 | diamantino
# Processing Record 47 of Set 5 | grindavik
# Processing Record 48 of Set 5 | zeya
# Processing Record 49 of Set 5 | aklavik
# Processing Record 50 of Set 5 | aswan
# Processing Record 1 of Set 6 | leshan
# Processing Record 2 of Set 6 | nantucket
# Processing Record 3 of Set 6 | aykhal
# Processing Record 4 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 6 | bowen
# Processing Record 6 of Set 6 | puerto escondido
# Processing Record 7 of Set 6 | sampit
# Processing Record 8 of Set 6 | pierre
# Processing Record 9 of Set 6 | kungurtug
# Processing Record 10 of Set 6 | berlevag
# Processing Record 11 of Set 6 | honningsvag
# Processing Record 12 of Set 6 | yulara
# Processing Record 13 of Set 6 | ulaangom
# Processing Record 14 of Set 6 | kavaratti
# Processing Record 15 of Set 6 | santa cruz
# Processing Record 16 of Set 6 | aleppo
# Processing Record 17 of Set 6 | yabelo
# Processing Record 18 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 19 of Set 6 | malakal
# Processing Record 20 of Set 6 | atikokan
# Processing Record 21 of Set 6 | bac giang
# Processing Record 22 of Set 6 | dwarka
# Processing Record 23 of Set 6 | vanderhoof
# Processing Record 24 of Set 6 | rognan
# Processing Record 25 of Set 6 | wundanyi
# Processing Record 26 of Set 6 | marystown
# Processing Record 27 of Set 6 | caravelas
# Processing Record 28 of Set 6 | leningradskiy
# Processing Record 29 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 6 | abha
# Processing Record 31 of Set 6 | mitsamiouli
# Processing Record 32 of Set 6 | key west
# Processing Record 33 of Set 6 | carnarvon
# Processing Record 34 of Set 6 | golaghat
# Processing Record 35 of Set 6 | klaksvik
# Processing Record 36 of Set 6 | singaraja
# Processing Record 37 of Set 6 | strezhevoy
# Processing Record 38 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 6 | beringovskiy
# Processing Record 40 of Set 6 | pevek
# Processing Record 41 of Set 6 | puyang
# Processing Record 42 of Set 6 | half moon bay
# Processing Record 43 of Set 6 | port hedland
# Processing Record 44 of Set 6 | ahipara
# Processing Record 45 of Set 6 | douentza
# Processing Record 46 of Set 6 | aksu
# Processing Record 47 of Set 6 | sergeyevka
# Processing Record 48 of Set 6 | bingen
# Processing Record 49 of Set 6 | sabaudia
# Processing Record 50 of Set 6 | lugovoy
# Processing Record 1 of Set 7 | takestan
# Processing Record 2 of Set 7 | damara
# Processing Record 3 of Set 7 | bandarbeyla
# Processing Record 4 of Set 7 | methoni
# Processing Record 5 of Set 7 | alexandria
# Processing Record 6 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 7 | zemio
# Processing Record 8 of Set 7 | kathu
# Processing Record 9 of Set 7 | chuy
# Processing Record 10 of Set 7 | atlantic city
# Processing Record 11 of Set 7 | alice town
# Processing Record 12 of Set 7 | necochea
# Processing Record 13 of Set 7 | fianarantsoa
# Processing Record 14 of Set 7 | cururupu
# Processing Record 15 of Set 7 | thap than
# Processing Record 16 of Set 7 | lewiston
# Processing Record 17 of Set 7 | atasu
# Processing Record 18 of Set 7 | lockhart
# Processing Record 19 of Set 7 | inongo
# Processing Record 20 of Set 7 | tyumentsevo
# Processing Record 21 of Set 7 | kormilovka
# Processing Record 22 of Set 7 | krasnokamensk
# Processing Record 23 of Set 7 | abonnema
# Processing Record 24 of Set 7 | gasan
# Processing Record 25 of Set 7 | karratha
# Processing Record 26 of Set 7 | cayenne
# Processing Record 27 of Set 7 | stykkisholmur
# Processing Record 28 of Set 7 | ossora
# Processing Record 29 of Set 7 | taruma
# Processing Record 30 of Set 7 | mastung
# Processing Record 31 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 7 | maniitsoq
# Processing Record 33 of Set 7 | mudhol
# Processing Record 34 of Set 7 | carpinteria
# Processing Record 35 of Set 7 | te anau
# Processing Record 36 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 7 | foumban
# Processing Record 38 of Set 7 | sojat
# Processing Record 39 of Set 7 | esperance
# Processing Record 40 of Set 7 | isla vista
# Processing Record 41 of Set 7 | ghanzi
# Processing Record 42 of Set 7 | ancud
# Processing Record 43 of Set 7 | yerbogachen
# Processing Record 44 of Set 7 | san ignacio
# Processing Record 45 of Set 7 | yvetot
# Processing Record 46 of Set 7 | brae
# Processing Record 47 of Set 7 | kalmunai
# Processing Record 48 of Set 7 | tingo maria
# Processing Record 49 of Set 7 | kupang
# Processing Record 50 of Set 7 | coquimbo
# Processing Record 1 of Set 8 | ankang
# Processing Record 2 of Set 8 | sisophon
# Processing Record 3 of Set 8 | roebourne
# Processing Record 4 of Set 8 | bairiki
# Processing Record 5 of Set 8 | namatanai
# Processing Record 6 of Set 8 | dali
# Processing Record 7 of Set 8 | new norfolk
# Processing Record 8 of Set 8 | bayevo
# Processing Record 9 of Set 8 | igrim
# Processing Record 10 of Set 8 | paamiut
# Processing Record 11 of Set 8 | miri
# Processing Record 12 of Set 8 | ust-omchug
# Processing Record 13 of Set 8 | chiredzi
# Processing Record 14 of Set 8 | namibe
# Processing Record 15 of Set 8 | puerto ayacucho
# Processing Record 16 of Set 8 | lubbock
# Processing Record 17 of Set 8 | kaitangata
# Processing Record 18 of Set 8 | port hueneme
# Processing Record 19 of Set 8 | fallon
# Processing Record 20 of Set 8 | sola
# Processing Record 21 of Set 8 | cuamba
# Processing Record 22 of Set 8 | katsuura
# Processing Record 23 of Set 8 | eureka
# Processing Record 24 of Set 8 | cherskiy
# Processing Record 25 of Set 8 | asfi
# Processing Record 26 of Set 8 | shelabolikha
# Processing Record 27 of Set 8 | kapuskasing
# Processing Record 28 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 8 | ostrovnoy
# Processing Record 30 of Set 8 | taoudenni
# Processing Record 31 of Set 8 | deputatskiy
# Processing Record 32 of Set 8 | opuwo
# Processing Record 33 of Set 8 | taltal
# Processing Record 34 of Set 8 | nanortalik
# Processing Record 35 of Set 8 | safford
# Processing Record 36 of Set 8 | spirit river
# Processing Record 37 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 8 | la ronge
# Processing Record 39 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 8 | kehychivka
# Processing Record 41 of Set 8 | dhidhdhoo
# Processing Record 42 of Set 8 | lexington
# Processing Record 43 of Set 8 | hovin
# Processing Record 44 of Set 8 | linxia
# Processing Record 45 of Set 8 | ladario
# Processing Record 46 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 8 | kidal
# Processing Record 48 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 49 of Set 8 | henties bay
# Processing Record 50 of Set 8 | inuvik
# Processing Record 1 of Set 9 | alofi
# Processing Record 2 of Set 9 | palestine
# Processing Record 3 of Set 9 | ponta do sol
# Processing Record 4 of Set 9 | haines junction
# Processing Record 5 of Set 9 | tabuk
# Processing Record 6 of Set 9 | korsakov
# Processing Record 7 of Set 9 | safaga
# Processing Record 8 of Set 9 | fortuna
# Processing Record 9 of Set 9 | bartica
# Processing Record 10 of Set 9 | sapernoye
# Processing Record 11 of Set 9 | seoul
# Processing Record 12 of Set 9 | ziarat
# Processing Record 13 of Set 9 | ipixuna
# Processing Record 14 of Set 9 | mattru
# Processing Record 15 of Set 9 | maldonado
# Processing Record 16 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 9 | touros
# Processing Record 18 of Set 9 | ayorou
# Processing Record 19 of Set 9 | tukuyu
# Processing Record 20 of Set 9 | nioro
# Processing Record 21 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 9 | odweyne
# Processing Record 23 of Set 9 | decatur
# Processing Record 24 of Set 9 | charters towers
# Processing Record 25 of Set 9 | puerto leguizamo
# Processing Record 26 of Set 9 | wenatchee
# Processing Record 27 of Set 9 | saint-georges
# Processing Record 28 of Set 9 | fairbanks
# Processing Record 29 of Set 9 | richards bay
# Processing Record 30 of Set 9 | phrai bung
# City not found. Skipping...
# Processing Record 31 of Set 9 | sikonge
# Processing Record 32 of Set 9 | atambua
# Processing Record 33 of Set 9 | broome
# Processing Record 34 of Set 9 | port-gentil
# Processing Record 35 of Set 9 | plover
# Processing Record 36 of Set 9 | tantoyuca
# Processing Record 37 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 9 | bayir
# Processing Record 39 of Set 9 | grand gaube
# Processing Record 40 of Set 9 | esfahan
# Processing Record 41 of Set 9 | axim
# Processing Record 42 of Set 9 | venado
# Processing Record 43 of Set 9 | timbiqui
# Processing Record 44 of Set 9 | khonsa
# Processing Record 45 of Set 9 | natal
# Processing Record 46 of Set 9 | arcachon
# Processing Record 47 of Set 9 | san juan
# Processing Record 48 of Set 9 | adeje
# Processing Record 49 of Set 9 | swinford
# Processing Record 50 of Set 9 | dudinka
# Processing Record 1 of Set 10 | saint-pierre
# Processing Record 2 of Set 10 | cardston
# Processing Record 3 of Set 10 | hasanabad
# Processing Record 4 of Set 10 | dunedin
# Processing Record 5 of Set 10 | mayskiy
# Processing Record 6 of Set 10 | san jose
# Processing Record 7 of Set 10 | filingue
# Processing Record 8 of Set 10 | westport
# Processing Record 9 of Set 10 | tall kayf
# Processing Record 10 of Set 10 | buraydah
# Processing Record 11 of Set 10 | lunca muresului
# Processing Record 12 of Set 10 | svetlogorsk
# Processing Record 13 of Set 10 | husavik
# Processing Record 14 of Set 10 | niamey
# Processing Record 15 of Set 10 | mehamn
# Processing Record 16 of Set 10 | udimskiy
# Processing Record 17 of Set 10 | kotido
# Processing Record 18 of Set 10 | ellisras
# Processing Record 19 of Set 10 | kindu
# Processing Record 20 of Set 10 | nemuro
# Processing Record 21 of Set 10 | dukat
# Processing Record 22 of Set 10 | smithfield
# Processing Record 23 of Set 10 | baracoa
# Processing Record 24 of Set 10 | biltine
# Processing Record 25 of Set 10 | shimoda
# Processing Record 26 of Set 10 | clyde river
# Processing Record 27 of Set 10 | zaysan
# Processing Record 28 of Set 10 | kanniyakumari
# Processing Record 29 of Set 10 | anadyr
# Processing Record 30 of Set 10 | pangai
# Processing Record 31 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 10 | aschersleben
# Processing Record 33 of Set 10 | faya
# Processing Record 34 of Set 10 | biak
# Processing Record 35 of Set 10 | baruun-urt
# Processing Record 36 of Set 10 | hambantota
# Processing Record 37 of Set 10 | bilibino
# Processing Record 38 of Set 10 | jablah
# Processing Record 39 of Set 10 | princesa isabel
# Processing Record 40 of Set 10 | novoorsk
# Processing Record 41 of Set 10 | sao felix do xingu
# Processing Record 42 of Set 10 | creel
# Processing Record 43 of Set 10 | aktas
# Processing Record 44 of Set 10 | tsiroanomandidy
# Processing Record 45 of Set 10 | hamilton
# Processing Record 46 of Set 10 | nizhnevartovsk
# Processing Record 47 of Set 10 | bubaque
# Processing Record 48 of Set 10 | antanifotsy
# Processing Record 49 of Set 10 | karaton
# Processing Record 50 of Set 10 | beloha
# Processing Record 1 of Set 11 | mazara del vallo
# Processing Record 2 of Set 11 | matamoros
# Processing Record 3 of Set 11 | chake chake
# Processing Record 4 of Set 11 | gweru
# Processing Record 5 of Set 11 | zhezkazgan
# Processing Record 6 of Set 11 | laguna
# Processing Record 7 of Set 11 | streator
# Processing Record 8 of Set 11 | lodwar
# Processing Record 9 of Set 11 | tonj
# Processing Record 10 of Set 11 | muskogee
# Processing Record 11 of Set 11 | vizinga
# Processing Record 12 of Set 11 | havre-saint-pierre
# Processing Record 13 of Set 11 | sao joao da barra
# Processing Record 14 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 11 | barugo
# Processing Record 16 of Set 11 | carnduff
# Processing Record 17 of Set 11 | insar
# Processing Record 18 of Set 11 | formosa
# Processing Record 19 of Set 11 | san patricio
# Processing Record 20 of Set 11 | sun city west
# Processing Record 21 of Set 11 | ronneby
# Processing Record 22 of Set 11 | oriximina
# Processing Record 23 of Set 11 | minsk
# Processing Record 24 of Set 11 | mandapam
# Processing Record 25 of Set 11 | guerrero negro
# Processing Record 26 of Set 11 | businga
# Processing Record 27 of Set 11 | cap malheureux
# Processing Record 28 of Set 11 | hit
# Processing Record 29 of Set 11 | poum
# Processing Record 30 of Set 11 | ballina
# Processing Record 31 of Set 11 | salalah
# Processing Record 32 of Set 11 | kanye
# Processing Record 33 of Set 11 | changji
# Processing Record 34 of Set 11 | puerto del rosario
# Processing Record 35 of Set 11 | lianzhou
# Processing Record 36 of Set 11 | raga
# Processing Record 37 of Set 11 | pontianak
# Processing Record 38 of Set 11 | rehoboth
# Processing Record 39 of Set 11 | riyadh
# Processing Record 40 of Set 11 | yabassi
# Processing Record 41 of Set 11 | chilakalurupet
# Processing Record 42 of Set 11 | fare
# Processing Record 43 of Set 11 | kaeo
# Processing Record 44 of Set 11 | tupik
# Processing Record 45 of Set 11 | athabasca
# Processing Record 46 of Set 11 | rio grande
# Processing Record 47 of Set 11 | port augusta
# Processing Record 48 of Set 11 | akom
# Processing Record 49 of Set 11 | hay river
# Processing Record 50 of Set 11 | minna
# Processing Record 1 of Set 12 | cajati
# Processing Record 2 of Set 12 | el balyana
# City not found. Skipping...
# Processing Record 3 of Set 12 | bathsheba
# Processing Record 4 of Set 12 | gol
# Processing Record 5 of Set 12 | wuwei
# Processing Record 6 of Set 12 | garm
# City not found. Skipping...
# Processing Record 7 of Set 12 | bend
# Processing Record 8 of Set 12 | heihe
# Processing Record 9 of Set 12 | qurayyat
# Processing Record 10 of Set 12 | taunggyi
# Processing Record 11 of Set 12 | tiznit
# Processing Record 12 of Set 12 | manicore
# Processing Record 13 of Set 12 | kapoeta
# Processing Record 14 of Set 12 | tuatapere
# Processing Record 15 of Set 12 | puerto rondon
# Processing Record 16 of Set 12 | tefe
# Processing Record 17 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 18 of Set 12 | akyab
# Processing Record 19 of Set 12 | belomorsk
# Processing Record 20 of Set 12 | sao geraldo do araguaia
# Processing Record 21 of Set 12 | kieta
# Processing Record 22 of Set 12 | biloela
# Processing Record 23 of Set 12 | buin
# Processing Record 24 of Set 12 | baiyin
# Processing Record 25 of Set 12 | greece
# Processing Record 26 of Set 12 | pontes e lacerda
# Processing Record 27 of Set 12 | makakilo city
# Processing Record 28 of Set 12 | uinskoye
# Processing Record 29 of Set 12 | beira
# Processing Record 30 of Set 12 | wewak
# Processing Record 31 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 32 of Set 12 | kyren
# Processing Record 33 of Set 12 | portland
# Processing Record 34 of Set 12 | boende
# Processing Record 35 of Set 12 | kayerkan
# Processing Record 36 of Set 12 | las vegas
# Processing Record 37 of Set 12 | skovorodino
# Processing Record 38 of Set 12 | ronne
# Processing Record 39 of Set 12 | altay
# Processing Record 40 of Set 12 | port moresby
# Processing Record 41 of Set 12 | ponta delgada
# Processing Record 42 of Set 12 | port blair
# Processing Record 43 of Set 12 | issia
# Processing Record 44 of Set 12 | ambanja
# Processing Record 45 of Set 12 | zalantun
# Processing Record 46 of Set 12 | pangnirtung
# Processing Record 47 of Set 12 | sorochinsk
# Processing Record 48 of Set 12 | nelspruit
# Processing Record 49 of Set 12 | muzhi
# Processing Record 50 of Set 12 | thabazimbi
# Processing Record 1 of Set 13 | sortavala
# Processing Record 2 of Set 13 | kloulklubed
# Processing Record 3 of Set 13 | paita
# Processing Record 4 of Set 13 | itoman
# Processing Record 5 of Set 13 | yar-sale
# Processing Record 6 of Set 13 | jumla
# Processing Record 7 of Set 13 | vestmanna
# Processing Record 8 of Set 13 | balakhninskiy
# Processing Record 9 of Set 13 | salinopolis
# Processing Record 10 of Set 13 | ust-tsilma
# Processing Record 11 of Set 13 | luena
# Processing Record 12 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 13 of Set 13 | nongpoh
# Processing Record 14 of Set 13 | boden
# Processing Record 15 of Set 13 | orange
# Processing Record 16 of Set 13 | antalaha
# Processing Record 17 of Set 13 | colonia
# Processing Record 18 of Set 13 | chicama
# Processing Record 19 of Set 13 | san rafael
# Processing Record 20 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 13 | sao jose da coroa grande
# Processing Record 22 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 13 | lhuntshi
# City not found. Skipping...
# Processing Record 24 of Set 13 | bonthe
# Processing Record 25 of Set 13 | toora-khem
# Processing Record 26 of Set 13 | viedma
# Processing Record 27 of Set 13 | myskhako
# Processing Record 28 of Set 13 | corozal
# Processing Record 29 of Set 13 | karpogory
# Processing Record 30 of Set 13 | tigil
# Processing Record 31 of Set 13 | dublin
# Processing Record 32 of Set 13 | sakakah
# Processing Record 33 of Set 13 | abu samrah
# Processing Record 34 of Set 13 | katherine
# Processing Record 35 of Set 13 | orodara
# Processing Record 36 of Set 13 | verdalsora
# City not found. Skipping...
# Processing Record 37 of Set 13 | agua verde
# Processing Record 38 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 39 of Set 13 | vatutinki
# Processing Record 40 of Set 13 | margate
# Processing Record 41 of Set 13 | bac lieu
# Processing Record 42 of Set 13 | aviles
# Processing Record 43 of Set 13 | west bay
# Processing Record 44 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 45 of Set 13 | dingli
# Processing Record 46 of Set 13 | port-cartier
# Processing Record 47 of Set 13 | hamadan
# Processing Record 48 of Set 13 | nuuk
# Processing Record 49 of Set 13 | lerwick
# Processing Record 50 of Set 13 | easton
# Processing Record 1 of Set 14 | saa
# Processing Record 2 of Set 14 | bonavista
# Processing Record 3 of Set 14 | de aar
# Processing Record 4 of Set 14 | tupaciguara
# Processing Record 5 of Set 14 | ambon
# Processing Record 6 of Set 14 | mount gambier
# Processing Record 7 of Set 14 | kamyshevatskaya
# Processing Record 8 of Set 14 | show low
# Processing Record 9 of Set 14 | fort-shevchenko
# Processing Record 10 of Set 14 | chapais
# Processing Record 11 of Set 14 | jacksonville
# Processing Record 12 of Set 14 | cockburn town
# Processing Record 13 of Set 14 | blythe
# Processing Record 14 of Set 14 | pakxan
# Processing Record 15 of Set 14 | keningau
# Processing Record 16 of Set 14 | the pas
# Processing Record 17 of Set 14 | agnibilekrou
# Processing Record 18 of Set 14 | rawson
# Processing Record 19 of Set 14 | thilogne
# City not found. Skipping...
# Processing Record 20 of Set 14 | north platte
# Processing Record 21 of Set 14 | udachnyy
# Processing Record 22 of Set 14 | leh
# Processing Record 23 of Set 14 | turochak
# Processing Record 24 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 14 | angoche
# Processing Record 26 of Set 14 | christchurch
# Processing Record 27 of Set 14 | kousseri
# Processing Record 28 of Set 14 | lata
# Processing Record 29 of Set 14 | vredendal
# Processing Record 30 of Set 14 | neryungri
# Processing Record 31 of Set 14 | kargasok
# Processing Record 32 of Set 14 | popondetta
# Processing Record 33 of Set 14 | acapulco
# Processing Record 34 of Set 14 | arroyo
# Processing Record 35 of Set 14 | bedesa
# Processing Record 36 of Set 14 | domoni
# Processing Record 37 of Set 14 | springdale
# Processing Record 38 of Set 14 | wladyslawowo
# Processing Record 39 of Set 14 | paidha
# Processing Record 40 of Set 14 | alyangula
# Processing Record 41 of Set 14 | macas
# Processing Record 42 of Set 14 | bonnyville
# Processing Record 43 of Set 14 | benghazi
# Processing Record 44 of Set 14 | spornoye
# Processing Record 45 of Set 14 | iskateley
# Processing Record 46 of Set 14 | vanimo
# Processing Record 47 of Set 14 | parras
# City not found. Skipping...
# Processing Record 48 of Set 14 | lasa
# Processing Record 49 of Set 14 | pecos
# Processing Record 50 of Set 14 | hami
# Processing Record 1 of Set 15 | kizhinga
# Processing Record 2 of Set 15 | sisimiut
# Processing Record 3 of Set 15 | doha
# Processing Record 4 of Set 15 | port macquarie
# Processing Record 5 of Set 15 | kikwit
# Processing Record 6 of Set 15 | sayyan
# Processing Record 7 of Set 15 | jhelum
# Processing Record 8 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 15 | ambilobe
# Processing Record 10 of Set 15 | mayo
# Processing Record 11 of Set 15 | qaqortoq
# Processing Record 12 of Set 15 | kaduna
# Processing Record 13 of Set 15 | south charleston
# Processing Record 14 of Set 15 | handwara
# City not found. Skipping...
# Processing Record 15 of Set 15 | port hardy
# Processing Record 16 of Set 15 | tacna
# Processing Record 17 of Set 15 | tessalit
# Processing Record 18 of Set 15 | sihora
# Processing Record 19 of Set 15 | maarianhamina
# Processing Record 20 of Set 15 | lazaro cardenas
# Processing Record 21 of Set 15 | sorong
# Processing Record 22 of Set 15 | canaries
# Processing Record 23 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 15 | hutang
# Processing Record 25 of Set 15 | kurya
# Processing Record 26 of Set 15 | lorengau
# Processing Record 27 of Set 15 | merauke
# Processing Record 28 of Set 15 | merritt
# Processing Record 29 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 15 | soe
# Processing Record 31 of Set 15 | sorland
# Processing Record 32 of Set 15 | tukrah
# Processing Record 33 of Set 15 | bedele
# Processing Record 34 of Set 15 | victor harbor
# Processing Record 35 of Set 15 | dawan
# Processing Record 36 of Set 15 | conway
# Processing Record 37 of Set 15 | baillif
# Processing Record 38 of Set 15 | yinchuan
# Processing Record 39 of Set 15 | yumen
# Processing Record 40 of Set 15 | ushtobe
# Processing Record 41 of Set 15 | baykit
# Processing Record 42 of Set 15 | ouahigouya
# Processing Record 43 of Set 15 | gidole
# Processing Record 44 of Set 15 | khuzdar
# Processing Record 45 of Set 15 | russell
# Processing Record 46 of Set 15 | beyneu
# Processing Record 47 of Set 15 | zhangjiakou
# Processing Record 48 of Set 15 | aars
# Processing Record 49 of Set 15 | kashi
# Processing Record 50 of Set 15 | alamogordo
# Processing Record 1 of Set 16 | bad neustadt
# City not found. Skipping...
# Processing Record 2 of Set 16 | punta de bombon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tura  25.5198   90.2201     71.67        99          93
# 1  Komsomolskiy  40.4272   71.7189     58.42        47          31
# 2       Rikitea -23.1203 -134.9692     74.77        67          41
# 3         Kalat  29.0225   66.5916     54.77        22           0
# 4          Nata   8.3333  -80.5167     76.42        89          53
# 5         Bluff -46.6000  168.3333     49.59        59          10
# 6  Punta Arenas -53.1500  -70.9167     44.71        61          20
# 7     Busselton -33.6500  115.3333     61.05        64          93
# 8       Mataura -46.1927  168.8643     57.96        40           1
# 9         Kapaa  22.0752 -159.3190     84.18        64           1
#
#    Wind Speed Country                 Date
# 0        3.36      IN  2021-10-21 00:41:26
# 1        9.22      UZ  2021-10-21 00:43:51
# 2       20.38      PF  2021-10-21 00:46:10
# 3        1.30      PK  2021-10-21 00:44:23
# 4        1.86      PA  2021-10-21 00:46:11
# 5        9.89      NZ  2021-10-21 00:46:11
# 6       11.50      CL  2021-10-21 00:41:18
# 7       15.97      AU  2021-10-21 00:46:12
# 8        2.30      NZ  2021-10-21 00:46:12
# 9        1.99      US  2021-10-21 00:46:13

# %%
# reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Date"]

# assign a new or the same DataFrame with new column order:
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tura      IN  25.5198   90.2201     71.67        99          93
# 1  Komsomolskiy      UZ  40.4272   71.7189     58.42        47          31
# 2       Rikitea      PF -23.1203 -134.9692     74.77        67          41
# 3         Kalat      PK  29.0225   66.5916     54.77        22           0
# 4          Nata      PA   8.3333  -80.5167     76.42        89          53
# 5         Bluff      NZ -46.6000  168.3333     49.59        59          10
# 6  Punta Arenas      CL -53.1500  -70.9167     44.71        61          20
# 7     Busselton      AU -33.6500  115.3333     61.05        64          93
# 8       Mataura      NZ -46.1927  168.8643     57.96        40           1
# 9         Kapaa      US  22.0752 -159.3190     84.18        64           1
#
#    Wind Speed                 Date
# 0        3.36  2021-10-21 00:41:26
# 1        9.22  2021-10-21 00:43:51
# 2       20.38  2021-10-21 00:46:10
# 3        1.30  2021-10-21 00:44:23
# 4        1.86  2021-10-21 00:46:11
# 5        9.89  2021-10-21 00:46:11
# 6       11.50  2021-10-21 00:41:18
# 7       15.97  2021-10-21 00:46:12
# 8        2.30  2021-10-21 00:46:12
# 9        1.99  2021-10-21 00:46:13

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
